# %%
import pandas as pd
import numpy as np 
import sklearn
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
import matplotlib.pyplot as plt
import re
import seaborn as sb
get_ipython().run_line_magic('matplotlib', 'inline')
get_ipython().run_line_magic('config', "InlineBackend.figure_format = 'retina'")

# %%
import pandas as pd

dataset1 = pd.read_csv(r"indian_express_headlines.csv")



dataset1.head()
# Out:
#                                             Headline  \
# 0  Sudha Murty in Rajya Sabha: Who are the other ...
# 1  Major takeaways from Congress first list for L...
# 2  BJP-TDP on the cusp of a poll deal, announceme...
# 3  Battleground Azamgarh: To retain Akhilesh’s fo...
# 4  As PM Modi announces another LPG price cut, wh...
#
#                                              Content          Publication Date
# 0  The philanthropist and former Infosys Foundati...  March 8, 2024  23:01 IST
# 1  Congress insiders say Rahul Gandhi, who has be...  March 8, 2024  23:31 IST
# 2  Chandrababu Naidu, Pawan Kalyan to meet Amit S...  March 8, 2024  21:14 IST
# 3  As SP looks to wrest control of its former str...  March 8, 2024  22:54 IST
# 4  The reduction of Rs 100 per cylinder comes jus...   March 8, 2024 16:17 IST

# %%
dataset1=pd.read_csv(r"indian_express_headlines.csv")
cols_of_interest=["Headline","Content"]
fn=dataset1[cols_of_interest]
print(fn.shape)
# Out:
# (17460, 2)

# %%
print(fn.describe())
# Out:
#                                                  Headline  \
# count                                               17460
# unique                                              17460
# top     Sudha Murty in Rajya Sabha: Who are the other ...
# freq                                                    1
#
#                                                   Content
# count                                               17452
# unique                                              17435
# top     Here we take a look at the major political eve...
# freq                                                    6

# %%
fn.dropna(subset=['Content','Headline'],inplace=True)
print(fn.shape)
fn.head(100)
# Out:
# (17452, 2)
# C:\Users\sudha\AppData\Local\Temp\ipykernel_21180\1983196909.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fn.dropna(subset=['Content','Headline'],inplace=True)
#                                              Headline  \
# 0   Sudha Murty in Rajya Sabha: Who are the other ...
# 1   Major takeaways from Congress first list for L...
# 2   BJP-TDP on the cusp of a poll deal, announceme...
# 3   Battleground Azamgarh: To retain Akhilesh’s fo...
# 4   As PM Modi announces another LPG price cut, wh...
# ..                                                ...
# 95  Himachal Congress turmoil: Away from CM’s brea...
# 96  The long blood line of Himachal rebellion: A f...
# 97  CAA again on horizon, Assam Opposition prepare...
# 98  Ally CPM’s mouthpiece takes a swipe at Congres...
# 99  Haryana BJP puts forward its Lok Sabha list: A...
#
#                                               Content
# 0   The philanthropist and former Infosys Foundati...
# 1   Congress insiders say Rahul Gandhi, who has be...
# 2   Chandrababu Naidu, Pawan Kalyan to meet Amit S...
# 3   As SP looks to wrest control of its former str...
# 4   The reduction of Rs 100 per cylinder comes jus...
# ..                                                ...
# 95  While they were undecided about what they were...
# 96  The two could not have been further apart, fro...
# 97  16 parties hand over memorandum to President a...
# 98  While attacking BJP, People's Democracy editor...
# 99  Recent entrants Kuldeep Bishnoi and Ashok Tanw...
#
# [100 rows x 2 columns]

# %%
fn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17452 entries, 0 to 17459
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Headline  17452 non-null  object
#  1   Content   17452 non-null  object
# dtypes: object(2)
# memory usage: 409.0+ KB

# %%
df=fn
df['fakeness'] = 0
df.head(60)
# Out:
# C:\Users\sudha\AppData\Local\Temp\ipykernel_21180\3537293374.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fakeness'] = 0
#                                              Headline  \
# 0   Sudha Murty in Rajya Sabha: Who are the other ...
# 1   Major takeaways from Congress first list for L...
# 2   BJP-TDP on the cusp of a poll deal, announceme...
# 3   Battleground Azamgarh: To retain Akhilesh’s fo...
# 4   As PM Modi announces another LPG price cut, wh...
# 5   BJP’s choice to take on Asaduddin Owaisi in Hy...
# 6   As RSS apex body meets, Manipur, Sandeshkhali,...
# 7   Decode Politics: Why TDP is in Delhi for anoth...
# 8   Today in Politics: Is BJP set to seal alliance...
# 9   24 years after Biju Patnaik confidant was expe...
# 10  Congress CEC clears Rahul Gandhi from Wayanad,...
# 11  ‘Our apprenticeship promise is like MNREGA. We...
# 12  As Rahul Yatra enters Gujarat today, a battere...
# 13  Another shock for Congress, this time in Keral...
# 14  As Congress’s former Varanasi MP joins BJP, wh...
# 15  Alarm bells in INDIA as AIMIM plans to expand ...
# 16  Assam TMC says seat-sharing chances with INDIA...
# 17  Decode Politics: Why BJD, BJP alliance makes s...
# 18  Today in Politics: All eyes on PM Modi’s Kashm...
# 19  15 years after snapping ties, BJD set to retur...
# 20  Days after Tripura accord, Oppn Tipra set to j...
# 21  Tapas Roy joins BJP after quitting TMC, says h...
# 22  As Sandeshkhali puts women at heart of Bengal ...
# 23  The collapse of a party: Days to go for Lok Sa...
# 24  30-32 seats for party, 16-18 for allies: BJP h...
# 25  As PM Modi comes bearing schemes for Kashmir, ...
# 26  Akhilesh goes all out to boost SP first family...
# 27  Meet sole Muslim face in BJP LS list so far: C...
# 28  New names less than half; more changes in seat...
# 29  Arvind Kejriwal as ‘Shravan Kumar’, ‘Ram Rajya...
# 30  Under Karnataka pact, BJP, JD(S) faces may swi...
# 31  Meet new faces in Yogi Cabinet: Purvanchal pro...
# 32  Body blow for INDIA bloc in J&K: National Conf...
# 33  Congress likely to announce LS poll promises f...
# 34  Today in Politics: PM Modi back in Bengal, Con...
# 35  ‘India a subcontinent, not country’, remarks o...
# 36  First Lalu, now A Raja: INDIA bloc keeps lobbi...
# 37  Thiruvananthapuram battle of the biggies: BJP ...
# 38  Justice Abhijit Gangopadhyay not the first: Wh...
# 39  From the Urdu Press: ‘What became of Modi guar...
# 40  6 sitting MPs dropped, more likely: A look at ...
# 41  A lot riding on women’s votes, TMC and BJP go ...
# 42  Sticking to script? When films meet pollsSubsc...
# 43  ‘We joined Samajwadi Party for being a party o...
# 44  Under ED scanner over ‘govt fund laundering’, ...
# 45  Today in Politics: PM Modi in Odisha amid spec...
# 46  Gujarat Congress exodus continues, another big...
# 38  While former CJI K Subba Rao stepped down thre...         0
# 39  ‘Modi had made several big promises to the cou...         0
# 40  Pragya Thakur, who drew PM's rap for her Godse...         0
# 41  While women are a crucial constituency for the...         0
# 42  Like 2019, Bollywood has lined up a series of ...         0
# 43  Manoj Pandey, among the SP MLAs believed to ha...         0
# 44  A TV channel 'sting' in 2012 purportedly uncov...         0
# 45  Plus, Amit Shah heads to Maharashtra to resolv...         0
# 46  Former LoP Arjun Modhwadia slams Congress stan...         0
# 47  Yet to announce future plans, Tapas Roy, who w...         0
# 48  Wins both the Senior Deputy Mayor and Deputy M...         0
# 49  Student leader from JNU, the newly elected Raj...         0
# 50  Prime Minister to address BJP Mahila Morcha me...         0
# 51  With the contours of their seats changed, Gaur...         0
# 52  JMM MPs Suraj Mandal, Shibu Soren, Simon Maran...         0
# 53  BJP is facing internal differences as well as ...         0
# 54  Amid reports of divisions over Bansuri Swaraj’...         0
# 55  In January, the judge hit the headlines after ...         0
# 56  Plus, Supreme Court verdict on whether legisla...         0
# 57  Mohan Yadav takes a dig at Akhilesh Yadav at a...         0
# 58  For more than two years, both in his judicial ...         0
# 59  The party's manifesto committee, headed by for...         0

# %%
tdf = TfidfVectorizer(stop_words='english',ngram_range=(1,2) )
df=df.head(4000)
vectorizer = tdf.fit(df.Content.values.astype('U'))
transformed_text = vectorizer.transform(df.Content.values.astype('U'))
transformed_title = vectorizer.transform(df.Headline.values.astype('U'))

# %%
len(df)
# Out:
# 4000

# %%
import numpy as np

def getTfidfTermScores(feature_names, transformed_title):
    term_corpus_dict = {}
    for term_ind, term in enumerate(feature_names):
        term_name = feature_names[term_ind]
        term_corpus_dict[term_name] = np.sum(transformed_title.T[term_ind].toarray())
        
    return term_corpus_dict

# Assuming you have already defined 'tdf' and 'transformed_title'

# Get feature names
feature_names = tdf.get_feature_names_out()

# Call the function
term_corpus_dict = getTfidfTermScores(feature_names, transformed_title)

# %%
def getSortedTfidfScores(term_corpus_dict):
    sortedIndices = np.argsort( list(term_corpus_dict.values()))[::-1]
    termNames = np.array(list(term_corpus_dict.keys()))
    scores = np.array(list(term_corpus_dict.values()))
    termNames = termNames[sortedIndices]
    scores = scores[sortedIndices]
    return termNames, scores


termNames, scores = getSortedTfidfScores(term_corpus_dict)

# %%
def plotTfidfScores(scores,termNames, n_words = 75):
    fig = plt.figure(figsize = (14, 18))
    override = {'fontsize': 'large'}
    fig.add_subplot(221)   
    n_words = 75
    sb.set()
    sb.barplot(x = scores[:n_words], y = termNames[:n_words]);
    plt.title("TFIDF - Importance of Top {0} Terms".format(n_words));
    plt.xlabel("TFIDF Score");




plotTfidfScores(scores, termNames,  n_words = 75)


df.to_csv("legit_cleaned.csv")
